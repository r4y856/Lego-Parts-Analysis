# %%
import duckdb
import pandas as pd
import os
import fastparquet

# %%
conn = duckdb.connect("lego.db", read_only=True)

# %%
#verify tables and number of rows

tables = conn.sql("SHOW TABLES").fetchall() #sql command native to duckdb, to retrieve all table names


#print row count per table in an ASCII table 
print(f"{'Table Name':<25} | {'Total Rows':>10}")
print("-" * 40)

for table in tables:
    t_name = table[0]
    count = conn.sql(f"SELECT COUNT(*) FROM {t_name}").fetchone()[0]
    print(f"{t_name:<25} | {count:>10,}")
# Out:
# Table Name                | Total Rows
# ----------------------------------------
# colors                    |        275
# elements                  |    110,700
# inventories               |     45,518
# inventory_minifigs        |     25,142
# inventory_parts           |  1,497,894
# inventory_sets            |      4,983
# minifigs                  |     16,740
# part_categories           |         76
# part_relationships        |     36,130
# parts                     |     62,460
# sets                      |     26,870
# themes                    |        494

# %%
#store dataframes of each table as a dictionary
dfs = {}

for table in tables:
    t = table[0]
    dfs[t] = conn.sql(f"SELECT * FROM {t}").df()

# %%
pd.set_option("display.width", 1000)

# %%
#table memory usage before cleaning and typecasting
total_bytes = sum(df.memory_usage(deep=True).sum() for df in dfs.values())
total_mb = total_bytes / (1024 ** 2)
print(f"Combined Memory Usage: {total_mb:.2f} MB")
# Out:
# Combined Memory Usage: 313.55 MB

# %%
#table info before cleaning and typecasting
for name, df in dfs.items():
    print(f"rows in '{name}': {len(df)}")
    print(df.info())
    print()
    print("------------------------------------------------------------------------------------------------------------------------")
    print()
# Out:
# rows in 'colors': 275
# <class 'pandas.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         275 non-null    int64
#  1   name       275 non-null    str
#  2   rgb        275 non-null    str
#  3   is_trans   275 non-null    bool
#  4   num_parts  275 non-null    int64
#  5   num_sets   275 non-null    int64
#  6   y1         273 non-null    Int64
#  7   y2         273 non-null    Int64
# dtypes: Int64(2), bool(1), int64(3), str(2)
# memory usage: 16.0 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'elements': 110700
# <class 'pandas.DataFrame'>
# RangeIndex: 110700 entries, 0 to 110699
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   element_id  110700 non-null  int64
#  1   part_num    110700 non-null  str
#  2   color_id    110700 non-null  int64
#  3   design_id   89252 non-null   Int64
# dtypes: Int64(1), int64(2), str(1)
# memory usage: 3.5 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventories': 45518
# <class 'pandas.DataFrame'>
# RangeIndex: 45518 entries, 0 to 45517
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       45518 non-null  int64
#  1   version  45518 non-null  int64
#  2   set_num  45518 non-null  str
# dtypes: int64(2), str(1)
# memory usage: 1.0 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventory_minifigs': 25142
# <class 'pandas.DataFrame'>
# RangeIndex: 25142 entries, 0 to 25141
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  25142 non-null  int64
#  1   fig_num       25142 non-null  str
#  2   quantity      25142 non-null  int64
# dtypes: int64(2), str(1)
# memory usage: 589.4 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventory_parts': 1497894
# <class 'pandas.DataFrame'>
# RangeIndex: 1497894 entries, 0 to 1497893
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   inventory_id  1497894 non-null  int64
#  1   part_num      1497894 non-null  str
#  2   color_id      1497894 non-null  int64
#  3   quantity      1497894 non-null  int64
#  4   is_spare      1497894 non-null  bool
#  5   img_url       1490550 non-null  str
# dtypes: bool(1), int64(3), str(2)
# memory usage: 58.6 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventory_sets': 4983
# <class 'pandas.DataFrame'>
# RangeIndex: 4983 entries, 0 to 4982
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  4983 non-null   int64
#  1   set_num       4983 non-null   str
#  2   quantity      4983 non-null   int64
# dtypes: int64(2), str(1)
# memory usage: 116.9 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'minifigs': 16740
# <class 'pandas.DataFrame'>
# RangeIndex: 16740 entries, 0 to 16739
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fig_num    16740 non-null  str
#  1   name       16740 non-null  str
#  2   num_parts  16740 non-null  int64
#  3   img_url    16740 non-null  str
# dtypes: int64(1), str(3)
# memory usage: 523.3 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'part_categories': 76
# <class 'pandas.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      76 non-null     int64
#  1   name    76 non-null     str
# dtypes: int64(1), str(1)
# memory usage: 1.3 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'part_relationships': 36130
# <class 'pandas.DataFrame'>
# RangeIndex: 36130 entries, 0 to 36129
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rel_type         36130 non-null  str
#  1   child_part_num   36130 non-null  str
#  2   parent_part_num  36130 non-null  str
# dtypes: str(3)
# memory usage: 846.9 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'parts': 62460
# <class 'pandas.DataFrame'>
# RangeIndex: 62460 entries, 0 to 62459
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   part_num       62460 non-null  str
#  1   name           62460 non-null  str
#  2   part_cat_id    62460 non-null  int64
#  3   part_material  62460 non-null  str
# dtypes: int64(1), str(3)
# memory usage: 1.9 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'sets': 26870
# <class 'pandas.DataFrame'>
# RangeIndex: 26870 entries, 0 to 26869
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    26870 non-null  str
#  1   name       26870 non-null  str
#  2   year       26870 non-null  int64
#  3   theme_id   26870 non-null  int64
#  4   num_parts  26870 non-null  int64
#  5   img_url    26870 non-null  str
# dtypes: int64(3), str(3)
# memory usage: 1.2 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'themes': 494
# <class 'pandas.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         494 non-null    int64
#  1   name       494 non-null    str
#  2   parent_id  344 non-null    Int64
# dtypes: Int64(1), int64(1), str(1)
# memory usage: 12.2 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
for name, df in dfs.items():
    for column_name, column in df.items():
        #tables with null values will use Pandas integers (Int..)
        if column.dtype == 'Int64':
            df[column_name] = df[column_name].astype('Int32')
        #tables without null values will use NumPy integers (int..)
        if column.dtype == 'int64':
            df[column_name] = df[column_name].astype('int32')

# %%
#table memory usage after cleaning and typecasting
total_bytes = sum(df.memory_usage(deep=True).sum() for df in dfs.values())
total_mb = total_bytes / (1024 ** 2)
print(f"Combined Memory Usage: {total_mb:.2f} MB")
# Out:
# Combined Memory Usage: 293.94 MB

# %%
#table info after cleaning and typecasting
for name, df in dfs.items():
    print(f"rows in '{name}': {len(df)}")
    print(df.info())
    print()
    print("------------------------------------------------------------------------------------------------------------------------")
    print()
# Out:
# rows in 'colors': 275
# <class 'pandas.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         275 non-null    int32
#  1   name       275 non-null    str
#  2   rgb        275 non-null    str
#  3   is_trans   275 non-null    bool
#  4   num_parts  275 non-null    int32
#  5   num_sets   275 non-null    int32
#  6   y1         273 non-null    Int32
#  7   y2         273 non-null    Int32
# dtypes: Int32(2), bool(1), int32(3), str(2)
# memory usage: 10.6 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'elements': 110700
# <class 'pandas.DataFrame'>
# RangeIndex: 110700 entries, 0 to 110699
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   element_id  110700 non-null  int32
#  1   part_num    110700 non-null  str
#  2   color_id    110700 non-null  int32
#  3   design_id   89252 non-null   Int32
# dtypes: Int32(1), int32(2), str(1)
# memory usage: 2.2 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventories': 45518
# <class 'pandas.DataFrame'>
# RangeIndex: 45518 entries, 0 to 45517
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       45518 non-null  int32
#  1   version  45518 non-null  int32
#  2   set_num  45518 non-null  str
# dtypes: int32(2), str(1)
# memory usage: 711.3 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventory_minifigs': 25142
# <class 'pandas.DataFrame'>
# RangeIndex: 25142 entries, 0 to 25141
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  25142 non-null  int32
#  1   fig_num       25142 non-null  str
#  2   quantity      25142 non-null  int32
# dtypes: int32(2), str(1)
# memory usage: 393.0 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventory_parts': 1497894
# <class 'pandas.DataFrame'>
# RangeIndex: 1497894 entries, 0 to 1497893
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   inventory_id  1497894 non-null  int32
#  1   part_num      1497894 non-null  str
#  2   color_id      1497894 non-null  int32
#  3   quantity      1497894 non-null  int32
#  4   is_spare      1497894 non-null  bool
#  5   img_url       1490550 non-null  str
# dtypes: bool(1), int32(3), str(2)
# memory usage: 41.4 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'inventory_sets': 4983
# <class 'pandas.DataFrame'>
# RangeIndex: 4983 entries, 0 to 4982
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  4983 non-null   int32
#  1   set_num       4983 non-null   str
#  2   quantity      4983 non-null   int32
# dtypes: int32(2), str(1)
# memory usage: 78.0 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'minifigs': 16740
# <class 'pandas.DataFrame'>
# RangeIndex: 16740 entries, 0 to 16739
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fig_num    16740 non-null  str
#  1   name       16740 non-null  str
#  2   num_parts  16740 non-null  int32
#  3   img_url    16740 non-null  str
# dtypes: int32(1), str(3)
# memory usage: 457.9 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'part_categories': 76
# <class 'pandas.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      76 non-null     int32
#  1   name    76 non-null     str
# dtypes: int32(1), str(1)
# memory usage: 1.0 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'part_relationships': 36130
# <class 'pandas.DataFrame'>
# RangeIndex: 36130 entries, 0 to 36129
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rel_type         36130 non-null  str
#  1   child_part_num   36130 non-null  str
#  2   parent_part_num  36130 non-null  str
# dtypes: str(3)
# memory usage: 846.9 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'parts': 62460
# <class 'pandas.DataFrame'>
# RangeIndex: 62460 entries, 0 to 62459
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   part_num       62460 non-null  str
#  1   name           62460 non-null  str
#  2   part_cat_id    62460 non-null  int32
#  3   part_material  62460 non-null  str
# dtypes: int32(1), str(3)
# memory usage: 1.7 MB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'sets': 26870
# <class 'pandas.DataFrame'>
# RangeIndex: 26870 entries, 0 to 26869
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    26870 non-null  str
#  1   name       26870 non-null  str
#  2   year       26870 non-null  int32
#  3   theme_id   26870 non-null  int32
#  4   num_parts  26870 non-null  int32
#  5   img_url    26870 non-null  str
# dtypes: int32(3), str(3)
# memory usage: 944.8 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------
#
# rows in 'themes': 494
# <class 'pandas.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         494 non-null    int32
#  1   name       494 non-null    str
#  2   parent_id  344 non-null    Int32
# dtypes: Int32(1), int32(1), str(1)
# memory usage: 8.3 KB
# None
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
#create folder of cleaned data tables
#parquet is used instead of csv because it remembers data types
os.makedirs("clean_data", exist_ok=True)

for table, df in dfs.items():
    df.to_parquet(f"clean_data/{table}.parquet", index=False)
